# %% [markdown]
# example 1: Manage a to do list

# %%
to_do_list=["buy gloseries","clean the house","pay bills"]
##adding task
to_do_list.append("shedule meeting")
to_do_list.append("go for a run")

##removing a completed task
to_do_list.remove("buy gloseries")


##check if a task is in todo list
if "pay bills" in to_do_list:
    print("dont forget to pay the bills")


print(" ")
print("to do list remaining:")
for task in to_do_list:
    print("-",task)
# Out:
# dont forget to pay the bills
#
# to do list remaining:
# - clean the house
# - pay bills
# - shedule meeting
# - go for a run

# %%
# Out:
# 4
