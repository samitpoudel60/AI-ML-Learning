# %%
##creating a new directory using os
##directory is a folder
import os

new_directory="created_using_OS"
os.mkdir(new_directory)
print("directory",new_directory,"created")
# Out:
# directory created_using_OS created

# %%
##listing all the files and folders for a directory
items=os.listdir(".")  ## . means we are looking at the current workuing location
print(items)
# Out:
# ['created_using_OS', 'custom_package', 'destination.txt', 'example.csv', 'execute_modules.py', 'file_paths.ipynb', 'importing_modules.ipynb', 'source.txt', 'standard_library.ipynb', 'test_dir']

# %%
### joinging paths 
## one of the most important functions

dir_name="folder"
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
## if i want to get it with my cuirrent working dfirectory i can
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# c:\Users\LQQ\Desktop\AI_ML\PYTHON\modules_packages\folder\file.txt

# %%
path="example.csv"
if os.path.exists(path):
    print("the path",path,"exists")
else:
    print("the path",path,"does not exists")
# Out:
# the path example.csv exists

# %%
##checking if a path is a file or directory
import os

path = "custom_package"

if os.path.isfile(path):
    print(path, "is a file")
elif os.path.isdir(path):
    print(path, " is a directory")
else:
    print(path, " does not exist")
# Out:
# custom_package  is a directory

# %%
##absolute path is the complete path and relative path means the only file/directory that i am in
##getting the absolute path
relative_path="example.csv"
abs_path=os.path.abspath(relative_path)
print(abs_path)##here i got the complete path
# Out:
# c:\Users\LQQ\Desktop\AI_ML\PYTHON\modules_packages\example.csv
