# %%
##integer example
age=25
print(type(age))
# Out:
# <class 'int'>

# %%
##floating point data type example
height=5.9
print(type(height))
# Out:
# <class 'float'>

# %%
##string data type example
name="John Doe"
print(type(name))
# Out:
# <class 'str'>

# %%
##bollean data type example
is_student=True
print(type(is_student))
# Out:
# <class 'bool'>

# %%
##common errors we face
#result=10+"hello"  #TypeError: unsupported operand type(s) for +: 'int' and 'str'
#this can be solver by

result=str(10)+"hello"
print(result)
# Out:
# 10hello

# %%
str="samit"
print(str.capitalize())
# Out:
# Samit
