# %%
##basic syantax of python
"""this is for double line comment
    use this thriple cotes for multi line comment
"""

# %%
##pyython is case sensitive language
name="LQQ"
Name="abc"
print(name)
print(Name)
# Out:
# LQQ
# abc

# %%
##indentation is very important in python
##python uses indentation to define a block of code
##consistent use of spaces and tabs is important
##the standard practice is to use 4 spaces per indentation level
age=32
if age>18:
    print("you are eligible to vote")
    print("have a nice day")
else:
    print("you are not eligible to vote")
    print("sorry")
# Out:
# you are eligible to vote
# have a nice day

# %%
##line continuation using backslash
##backslash continues the operation of next line 
total= 1 + 2 + 3 +\
4+ 5 + 6
print(total)
# Out:
# 21

# %%
##multiple statements in a single line using semicolon
##use semicolon to seperate multiple statements in a single line and execute them sequentially
a=5; b=10; c=a+b; print(c)    ##last will not have semicolon
# Out:
# 15

# %%
##understanding semnatics in python
x=10
y=20
sum=x+y
print("the sum of", x, "and", y, "is", sum)

# %%
##type interference in python
age=22
name="LQQ"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
variable=22
print(type(variable))
variable="LQQ"
print(type(variable))
print(variable)
# Out:
# <class 'int'>
# <class 'str'>
# LQQ

# %%
if True:
    print("This is true")
else:
    print("This is false")
# Out:
# This is true
