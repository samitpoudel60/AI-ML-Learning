# %%
##arithemic operations
a=10
b=3
add_result=a+b
sub_result=a-b
mul_result=a*b
div_result=a/b
floor_div_result=a//b
modulos_result=a%b
exponent_result=a**b

print(add_result)
print(sub_result)
print(mul_result)
print(div_result)
print(floor_div_result)
print(modulos_result)
print(exponent_result)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
##comparison operators
## == and !=
a=10
b=20
print(a==b)
print(a!=b)
# Out:
# False
# True

# %%
str1="samit"
str2="Samit"
print(str1==str2)##case sensative
print(str1!=str2)
# Out:
# False
# True

# %%
##grater than and less than
num1=50
num2=30
print(num1>num2)
# Out:
# True

# %%
print(num1<num2)
# Out:
# False

# %%
##greater than or equal to and less than or equal to
num3=30
num4=30
print(num3>=num4)
# Out:
# True

# %%
print(num3<=num4)
# Out:
# True

# %%
##logial operations
## and , or , not

x=True
y=False
print(x and y)
print(x or y)
print(not x)
print(not y)
# Out:
# False
# True
# False
# True
